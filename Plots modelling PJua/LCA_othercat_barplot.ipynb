# %%
# Created 09 Jun 23
# To do barplot of LCA impact categories (preliminary results)
# Including LCA_used only (considering LCA based on capacity and with inverter replacement as S0, used energy)
# check Jupyter notebook version for plots: 'LCA_othercat_barplot'
# Some plots are saved in words: 'Chapter 5 thesis graveyard' & 'Ch5_prelresults_9Jun23'
# Useful to see summary table of results of other categories (see Jupyter notebook)
# and for trial of split axis plot although still not working 

# Beware that the csv imported is an older version of the LCA results

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Move to path where csv is saved
path = "/Users/po416/Library/CloudStorage/OneDrive-ImperialCollegeLondon/PhDOct2018/Projects (12Mar20)/LCA/Plots LCA PJua"
# maybe change path after i document it properly

cwd = os.getcwd()
cwd

os.chdir(path)

# %%
pwd
# Out:
# '/Users/po416/Library/CloudStorage/OneDrive-ImperialCollegeLondon/PhDOct2018/Projects (12Mar20)/LCA/Plots LCA PJua'

# %%
# Import results from LCA which are the copied values from tab 'S0_utilisation_rate' in
# excel 'Ch5 LCA Project Jua (6Jun23)' or 9Jun23, columns copied I, and columns P-V.
LCA_oc_used = pd.read_csv("LCA_cap_inv_used.csv")
# check type of columns
LCA_oc_used.dtypes
# Out:
# Site_name                 object
# County                    object
# Institution               object
# CC (kg CO2eq/kWh)        float64
# FE (kg 1,4-DCBeq/kWh)    float64
# HT (kg 1,4-DCBeq/kWh)    float64
# MD (kg Fe eq/kWh)        float64
# PMF (kg PM10eq/kWh)      float64
# TA (kg SO2eq/kWh)        float64
# ME (kg 1,4-DCBeq/kWh)    float64
# TE (kg 1,4-DCBeq/kWh)    float64
# dtype: object

# %%
LCA_oc_used.head().round(2)
# Out:
#                          Site_name   County Institution  CC (kg CO2eq/kWh)  \
# 0        AIC_Nadoto_Primary_School  Turkana      School               0.50
# 1  AIC_Nayanaekaton_Primary_School  Turkana      School               0.64
# 2      A_IC_Gangani_Primary_School    Kwale      School               0.38
# 3          Abagarse_Primary_School   Isiolo      School               0.71
# 4           Akadeli_Primary_School   Isiolo      School               0.30
#
#    FE (kg 1,4-DCBeq/kWh)  HT (kg 1,4-DCBeq/kWh)  MD (kg Fe eq/kWh)  \
# 0                   0.14                   0.95               0.33
# 1                   0.18                   1.22               0.42
# 2                   0.11                   0.71               0.24
# 3                   0.20                   1.34               0.46
# 4                   0.08                   0.56               0.19
#
#    PMF (kg PM10eq/kWh)  TA (kg SO2eq/kWh)  ME (kg 1,4-DCBeq/kWh)  \
# ...

# %%
LCA_oc_used.round(2)
# Out:
#                            Site_name        County Institution  \
# 0          AIC_Nadoto_Primary_School       Turkana      School
# 1    AIC_Nayanaekaton_Primary_School       Turkana      School
# 2        A_IC_Gangani_Primary_School         Kwale      School
# 3            Abagarse_Primary_School        Isiolo      School
# 4             Akadeli_Primary_School        Isiolo      School
# ..                               ...           ...         ...
# 161            Watala_Primary_School        Kilifi      School
# 162          Werugha_Health_facility  Taita_Taveta      Clinic
# 163             Yapha_Primary_School         Kwale      School
# 164            Ziwani_Primary_School        Kilifi      School
# 165       Ziyaradundo_Primary_School         Kwale      School
#
#      CC (kg CO2eq/kWh)  FE (kg 1,4-DCBeq/kWh)  HT (kg 1,4-DCBeq/kWh)  \
# 0                 0.50                   0.14                   0.95
# ...

# %%
LCA_oc_used.describe().round(4) # to see summary table of results
# Out:
#        CC (kg CO2eq/kWh)  FE (kg 1,4-DCBeq/kWh)  HT (kg 1,4-DCBeq/kWh)  \
# count           166.0000               166.0000               166.0000
# mean              0.4300                 0.1187                 0.8007
# std               0.2539                 0.0715                 0.4808
# min               0.1060                 0.0298                 0.2003
# 25%               0.2671                 0.0721                 0.4928
# 50%               0.3582                 0.0997                 0.6707
# 75%               0.5334                 0.1482                 0.9976
# max               1.9541                 0.5485                 3.6916
#
#        MD (kg Fe eq/kWh)  PMF (kg PM10eq/kWh)  TA (kg SO2eq/kWh)  \
# count           166.0000             166.0000           166.0000
# mean              0.2736               0.0015             0.0034
# std               0.1653               0.0009             0.0020
# min               0.0687               0.0004             0.0008
# ...

# %%
# Import library and set format for plotting
import seaborn as sns

# set style for formatting plots
sns.set(rc={"figure.dpi":300})
sns.set_context("notebook")  # change to paper maybe? I prefer notebook style i think...
sns.set_style("ticks") # with axis ticks, no background lines
# sns.set_style("whitegrid")

# %%
# data as it is
ax=sns.barplot(data=LCA_oc_used)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# ax.set_ylim(0, .005) #to see other impacts
# Out:
# [Text(0, 0, 'CC (kg CO2eq/kWh)'),
#  Text(1, 0, 'FE (kg 1,4-DCBeq/kWh)'),
#  Text(2, 0, 'HT (kg 1,4-DCBeq/kWh)'),
#  Text(3, 0, 'MD (kg Fe eq/kWh)'),
#  Text(4, 0, 'PMF (kg PM10eq/kWh)'),
#  Text(5, 0, 'TA (kg SO2eq/kWh)'),
#  Text(6, 0, 'ME (kg 1,4-DCBeq/kWh)'),
#  Text(7, 0, 'TE (kg 1,4-DCBeq/kWh)')]

# %%
# data as it is
ax=sns.barplot(data=LCA_oc_used)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax.set_ylim(0, .004) #to see other impacts
# Out:
# (0.0, 0.004)

# %%
# data as it is
ax=sns.barplot(data=LCA_oc_used, palette="Spectral")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# ax.set_ylim(0, .004) #to see other impacts
# Out:
# [Text(0, 0, 'CC (kg CO2eq/kWh)'),
#  Text(1, 0, 'FE (kg 1,4-DCBeq/kWh)'),
#  Text(2, 0, 'HT (kg 1,4-DCBeq/kWh)'),
#  Text(3, 0, 'MD (kg Fe eq/kWh)'),
#  Text(4, 0, 'PMF (kg PM10eq/kWh)'),
#  Text(5, 0, 'TA (kg SO2eq/kWh)'),
#  Text(6, 0, 'ME (kg 1,4-DCBeq/kWh)'),
#  Text(7, 0, 'TE (kg 1,4-DCBeq/kWh)')]

# %%
# data as it is
ax=sns.barplot(data=LCA_oc_used, palette="Spectral")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax.set_ylim(0, .004) #to see other impacts
# Out:
# (0.0, 0.004)

# %%
# Splitting axis - No me sale todavia 
f, (ax_top, ax_bottom) = plt.subplots(2, 1, sharex=True)
sns.barplot(data=LCA_oc_used, ax=ax_top)
sns.barplot(data=LCA_oc_used, ax=ax_bottom)

ax_top.set_ylim(bottom=.1)   # those limits are fake
ax_bottom.set_ylim(0, .004)

sns.despine(ax=ax_bottom)
sns.despine(ax=ax_top, bottom=True)

ax = ax_top
d = .015  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal

ax2 = ax_bottom
kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal

#remove one of the legend
ax_bottom.legend_.remove()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 23>()
#      20 ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
#      22 #remove one of the legend
# ---> 23 ax_bottom.legend_.remove()
#      24 plt.show()
#
# AttributeError: 'NoneType' object has no attribute 'remove'

# %%
# Useful links:
# https://www.statology.org/seaborn-barplot-color/
# https://matplotlib.org/3.1.0/gallery/subplots_axes_and_figures/broken_axis.html
# https://stackoverflow.com/questions/63726234/how-to-draw-a-broken-y-axis-catplot-graphes-with-seaborn

# "Ch5 LCA Project Jua (9Jun23)" or 6Jun23. So, if these change or something is wrong with them, 
# make plots again with new values using this code. Also this code is useful to see trial of
# splitting axis of a plot but it didn’t work so far.
